# %% [markdown]
# # Original Polyvore

# %%
from dataset.dataset import PolyvoreDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreDataset(data_dir="../data/polyvore_outfits/",
                     transform=transforms.ToTensor(),
                     filter_description=True)

# %%
len(ds)
# Out:
# 72152

# %%
image, metadata, id = ds[13]

print(metadata)

plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Img: {}".format(id))
plt.show()
# Out:
# short skirt in imitation leather with a tab and metal buckle at the sides and a concealed zip at the back unlined 100 viscose machine wash at 30˚

# %% [markdown]
# # Fashion Hash Net Polyvore

# %%
from dataset.dataset import PolyvoreFashionHashDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreFashionHashDataset(data_dir="../data/polyvore/",
                                transform=transforms.ToTensor())

# %%
len(ds)
# Out:
# 293680

# %%
image, vector, metadata, id = ds[0]

# %%
print(vector)
print(metadata)
plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Img: {}".format(id))
plt.show()
# Out:
# [ 0.49362503  0.69441192 -0.10652015 ... -1.33408498 -0.82244234
#  -0.23344939]
# {'text': "Black 'Babel' skirt from Stella McCartney featuring a draped design, side pockets and a rear zip fastening.", 'price': '$560', 'class': 'bottom', 'categories': ['Shop', 'STELLA McCARTNEY skirts', 'Knee Length Skirts', 'Skirts'], 'name': "Stella McCartney 'Babel' skirt"}
