# %%
from dataset.dataset import PolyvoreDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
ds = PolyvoreDataset(data_dir="./data/polyvore_outfits/",
                     transform=transforms.ToTensor())

# %%
image, metadata, id = ds[5]

print(metadata)

plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Label: {}".format(id))
plt.show()
# Out:
# {'url_name': 'candies jet simulated crystal stretch', 'description': '', 'catgeories': '', 'title': '', 'related': '', 'category_id': '106', 'semantic_category': 'jewellery'}
