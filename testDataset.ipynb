# %%
from dataset.dataset import PolyvoreDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreDataset(data_dir="./data/polyvore_outfits/",
                     transform=transforms.ToTensor())

# %%
image, metadata, id = ds[1000]

print(metadata)

plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Label: {}".format(id))
plt.show()
# Out:
# {'url_name': 'untitled', 'description': '', 'catgeories': '', 'title': '', 'related': '', 'category_id': '62', 'semantic_category': 'jewellery'}
