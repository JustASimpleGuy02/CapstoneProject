# %%
from dataset.dataset import PolyvoreDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreDataset(data_dir="./data/polyvore_outfits/",
                     transform=transforms.ToTensor())

# %%
image, metadata, id = ds[4]

print(metadata)

plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Label: {}".format(id))
plt.show()
# Out:
# i36033 001 dc3a9colletc3a9 donna scarpe womens fashion shoes pumps giuseppe zanotti pumps i36033 001 décolleté donna scarpe donna su giuseppe zanotti design giuseppe zanotti high heeled footwear heel pump shoes
