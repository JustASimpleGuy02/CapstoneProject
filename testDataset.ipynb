# %% [markdown]
# # Original Polyvore

# %%
from dataset.dataset import PolyvoreDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreDataset(data_dir="./data/polyvore_outfits/",
                     transform=transforms.ToTensor(),
                     filter_description=True)

# %%
len(ds)
# Out:
# 72152

# %%
image, metadata, id = ds[13]

print(metadata)

plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Img: {}".format(id))
plt.show()
# Out:
# short skirt in imitation leather with a tab and metal buckle at the sides and a concealed zip at the back unlined 100 viscose machine wash at 30˚

# %% [markdown]
# # Fashion Hash Net Polyvore

# %%
from dataset.dataset import PolyvoreFashionHashDataset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %matplotlib inline

# %%
ds = PolyvoreFashionHashDataset(data_dir="./data/polyvore/",
                                transform=transforms.ToTensor())

# %%
len(ds)
# Out:
# 293679

# %%
image, vector, metadata, id = ds[254331]

# %%
print(vector)
print(metadata)
plt.imshow(np.transpose(image.numpy(), (1,2,0)))
plt.title("Img: {}".format(id))
plt.show()
# Out:
# [0.34950081 0.05616581 0.85755418 ... 0.78666627 0.55656162 0.44326056]
# smooth rubber booties in beige pebbled leather trimmings throughout in black open toe black laceup closure perforations at inner sides white pebbled leather trim at base approx 1 platform 5 stiletto heel upper 100 rubber contrast 100 leather sole 100 leather made in italy
